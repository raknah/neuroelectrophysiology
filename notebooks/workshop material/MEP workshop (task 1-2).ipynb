# %% [markdown]
# # Intro to python x MEP extraction and analysis (task 1 and 2)

# %% [markdown]
# ,### In this workshop, we will be using the following standard libraries:
#
# as we progress, we will be using more niche libraries, but for now, these are the basics that you will probably use in every project for the rest of your life.

# %%
statement =  "I'm having an aneurysm"

counter = 0

while counter < 10:
    print(statement)
    counter *= 2
# Out:
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# I'm having an aneurysm
# ...

# %%
# numpy for numerical operations
import numpy as np

# pandas for creating and editing dataframes (spreadsheet-like data structures)
import pandas as pd 

# os for locating files and data on your computer
import os

# pickle for saving and loading data objects you create
import pickle

# matplotlib for plotting
import matplotlib.pyplot as plt

# %% [markdown]
# ## task zero: mess around and get comfortable
# make use of our building blocks (variables, lists, dictionaries, loops, conditionals)

# %%
# create a list called 'one' of numbers from 1 to 10

# create a dictionary called 'two' with the numbers as keys and their squares as values

# create a list called 'three' of the squares of the numbers from 1 to 10

three = []
for number in range(1, 11):
    three.append(number**2)
print(f'three: {three}')

# create a list called 'four' of the squares of the numbers from 1 to 10, but only if the number is even

# create a list called 'five' of the squares of the numbers from 1 to 10, but only if the number is odd

# create a list called 'six' of the squares of the numbers from 1 to 10, but only if the number is odd and the square is less than 50

# create a dictionary called 'seven' with the numbers as keys and their squares as values, but only if the number is odd
# Out:
# three: [1, 4, 9, 16, 25, 36, 49, 64, 81, 100]

# %% [markdown]
# ## task one: locate and load the data
# ### locate and load the spreadsheet into a pandas dataframe

# %%
# where is the data?
path_to_master_folder = '/Users/fomo/Documents/Research/UNIC Research/Motor Evoked Potentials Test'
path_to_csv = '/Users/fomo/Documents/Research/UNIC Research/Motor Evoked Potentials Test/MICE_EEG_2024 (93-102).csv'



# load the data into a pandas dataframe
spreadsheet = pd.read_csv(path_to_csv)

# what does the data look like?
print(spreadsheet.head())
# Out:
#                session animalID  cage  ear phenotype  phenoCode  subrec  \
# 0  2024-03-07_18-03-10     A571   NaN  NaN     5XFAD        2.0     1.0
# 1  2024-03-07_18-04-31     A571   NaN  NaN     5XFAD        2.0     1.0
# 2  2024-03-07_18-11-10     A571   NaN  NaN     5XFAD        2.0     1.0
# 3  2024-03-07_18-12-24     A571   NaN  NaN     5XFAD        2.0     1.0
# 4  2024-03-07_18-26-03     A573   NaN  NaN     5XFAD        2.0     1.0
#
#   sessionClass sessionType  currentLevel stim_lvl  isoflo  trials_from  \
# 0          MEP     sciatic          1.49      thr     1.9          1.0
# 1          MEP     sciatic          2.25     1.5x     1.9          1.0
# 2          MEP  spine_hump          2.25      thr     1.9          1.0
# 3          MEP  spine_hump          4.12     1.5x     1.9          1.0
# 4          MEP     sciatic          3.37      thr     1.9          1.0
#
#    trials_to                                              notes
# ...

# %% [markdown]
# ### locate the MEP data for a single session

# %% [markdown]
# ### load the MEP data for a single session

# %% [markdown]
# ### plotting and exploring the MEP data

# %%
# explore the MEP data, what's the shape?, what are the columns?, what are the values?

# %%
# plot the MEP data, what does it look like?

# %% [markdown]
# ## task two: identify the event channel and extract event timings
# ### visually inspect the raw data to identify the event channel

# %%
# visually inspect the raw data to identify the event channel

# %% [markdown]
# ### plotting and exploring the event channel

# %%
# plot the event channel, what does it look like? how could you extract the event timings?

# %%
### extract
